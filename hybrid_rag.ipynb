# %% [markdown]
# ## 📄 Hybrid RAG Pipeline: CUAD + Uploaded PDF

# %%
# Install necessary packages
# !pip install -q pymupdf faiss-cpu sentence-transformers
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 79.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.3/31.3 MB 59.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 100.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 83.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 54.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 67.7 MB/s eta 0:00:00

# %%
! unzip /content/data/full_contract_txt.zip
# Out:
# Archive:  /content/data/full_contract_txt.zip
#    creating: full_contract_txt/
#   inflating: full_contract_txt/2ThemartComInc_19990826_10-12G_EX-10.10_6700288_EX-10.10_Co-Branding Agreement_ Agency Agreement.txt
#   inflating: full_contract_txt/ABILITYINC_06_15_2020-EX-4.25-SERVICES AGREEMENT.txt
#   inflating: full_contract_txt/ACCELERATEDTECHNOLOGIESHOLDINGCORP_04_24_2003-EX-10.13-JOINT VENTURE AGREEMENT.txt
#   inflating: full_contract_txt/ACCURAYINC_09_01_2010-EX-10.31-DISTRIBUTOR AGREEMENT.txt
#   inflating: full_contract_txt/ADAMSGOLFINC_03_21_2005-EX-10.17-ENDORSEMENT AGREEMENT.txt
#   inflating: full_contract_txt/ADAPTIMMUNETHERAPEUTICSPLC_04_06_2017-EX-10.11-STRATEGIC ALLIANCE AGREEMENT.txt
#   inflating: full_contract_txt/ADIANUTRITION,INC_04_01_2005-EX-10.D2-RESELLER AGREEMENT.txt
#   inflating: full_contract_txt/ADMA BioManufacturing, LLC -  Amendment #3 to Manufacturing Agreement .txt
#   inflating: full_contract_txt/ADUROBIOTECH,INC_06_02_2020-EX-10.7-CONSULTING AGREEMENT(1).txt
#   inflating: full_contract_txt/ADUROBIOTECH,INC_06_02_2020-EX-10.7-CONSULTING AGREEMENT.txt
#   inflating: full_contract_txt/AFSALABANCORPINC_08_01_1996-EX-1.1-AGENCY AGREEMENT.txt
#   inflating: full_contract_txt/AgapeAtpCorp_20191202_10-KA_EX-10.1_11911128_EX-10.1_Supply Agreement.txt
#   inflating: full_contract_txt/AimmuneTherapeuticsInc_20200205_8-K_EX-10.3_11967170_EX-10.3_Development Agreement.txt
#   inflating: full_contract_txt/AIRSPANNETWORKSINC_04_11_2000-EX-10.5-Distributor Agreement.txt
#   inflating: full_contract_txt/AIRTECHINTERNATIONALGROUPINC_05_08_2000-EX-10.4-FRANCHISE AGREEMENT.txt
#   inflating: full_contract_txt/ALAMOGORDOFINANCIALCORP_12_16_1999-EX-1-AGENCY AGREEMENT.txt
#   inflating: full_contract_txt/ALCOSTORESINC_12_14_2005-EX-10.26-AGENCY AGREEMENT.txt
#   inflating: full_contract_txt/ALLIANCEBANCORPINCOFPENNSYLVANIA_10_18_2006-EX-1.2-AGENCY AGREEMENT.txt
#   inflating: full_contract_txt/AlliedEsportsEntertainmentInc_20190815_8-K_EX-10.19_11788293_EX-10.19_Content License Agreement.txt
#   inflating: full_contract_txt/AlliedEsportsEntertainmentInc_20190815_8-K_EX-10.34_11788308_EX-10.34_Sponsorship Agreement.txt
#   inflating: full_contract_txt/ALLISONTRANSMISSIONHOLDINGSINC_12_15_2014-EX-99.1-COOPERATION AGREEMENT.txt
#   inflating: full_contract_txt/AMBASSADOREYEWEARGROUPINC_11_17_1997-EX-10.28-ENDORSEMENT AGREEMENT.txt
#   inflating: full_contract_txt/AMERICANPHYSICIANSCAPITALINC_03_31_2003-EX-10.26-AGENCY AGREEMENT.txt
#   inflating: full_contract_txt/AMERICASSHOPPINGMALLINC_12_10_1999-EX-10.2-SITE DEVELOPMENT AND HOSTING AGREEMENT.txt
#   inflating: full_contract_txt/ANIXABIOSCIENCESINC_06_09_2020-EX-10.1-COLLABORATION AGREEMENT.txt
#   inflating: full_contract_txt/Antares Pharma, Inc. - Manufacturing Agreement.txt
#   inflating: full_contract_txt/Apollo Endosurgery - Manufacturing and Supply Agreement.txt
#   inflating: full_contract_txt/ArcaUsTreasuryFund_20200207_N-2_EX-99.K5_11971930_EX-99.K5_Development Agreement.txt
#   inflating: full_contract_txt/ArcGroupInc_20171211_8-K_EX-10.1_10976103_EX-10.1_Sponsorship Agreement.txt
#   inflating: full_contract_txt/ArconicRolledProductsCorp_20191217_10-12B_EX-2.7_11923804_EX-2.7_Trademark License Agreement.txt
#   inflating: full_contract_txt/ARMSTRONGFLOORING,INC_01_07_2019-EX-10.2-INTELLECTUAL PROPERTY AGREEMENT.txt
#   inflating: full_contract_txt/ArmstrongFlooringInc_20190107_8-K_EX-10.2_11471795_EX-10.2_Intellectual Property Agreement.txt
#   inflating: full_contract_txt/Array BioPharma Inc. - LICENSE, DEVELOPMENT AND COMMERCIALIZATION AGREEMENT.txt
#   inflating: full_contract_txt/ArtaraTherapeuticsInc_20200110_8-K_EX-10.5_11943350_EX-10.5_License Agreement.txt
#   inflating: full_contract_txt/ASHWORTHINC_01_29_1999-EX-10.(D)-PROMOTION AGREEMENT AND NANTZ COMMUNICATIONS, INC..txt
#   inflating: full_contract_txt/ASIANDRAGONGROUPINC_08_11_2005-EX-10.5-Reseller Agreement.txt
#   inflating: full_contract_txt/ASPIRITYHOLDINGSLLC_05_07_2012-EX-10.6-OUTSOURCING AGREEMENT.txt
#   inflating: full_contract_txt/ATENTOSA_07_06_2020-EX-99.1-JOINT FILING AGREEMENT.txt
#   inflating: full_contract_txt/ATHENSBANCSHARESCORP_11_02_2009-EX-1.2-AGENCY AGREEMENT , 2009.txt
#   inflating: full_contract_txt/ATMOSENERGYCORP_11_22_2002-EX-10.17-TRANSPORTATION SERVICE AGREEMENT.txt
#   inflating: full_contract_txt/AtnInternationalInc_20191108_10-Q_EX-10.1_11878541_EX-10.1_Maintenance Agreement.txt
#   inflating: full_contract_txt/AudibleInc_20001113_10-Q_EX-10.32_2599586_EX-10.32_Co-Branding Agreement_ Marketing Agreement_ Investment Distribution Agreement.txt
#   inflating: full_contract_txt/AULAMERICANUNITTRUST_04_24_2020-EX-99.8.77-SERVICING AGREEMENT.txt
#   inflating: full_contract_txt/AURASYSTEMSINC_06_16_2010-EX-10.25-STRATEGIC ALLIANCE AGREEMENT.txt
#   inflating: full_contract_txt/AzulSa_20170303_F-1A_EX-10.3_9943903_EX-10.3_Maintenance Agreement1.txt
#   inflating: full_contract_txt/AzulSa_20170303_F-1A_EX-10.3_9943903_EX-10.3_Maintenance Agreement2.txt
#   inflating: full_contract_txt/BABCOCK_WILCOXENTERPRISES,INC_08_04_2015-EX-10.17-INTELLECTUAL PROPERTY AGREEMENT between THE BABCOCK _ WILCOX COMPANY and BABCOCK _ WILCOX ENTERPRISES, INC..txt
#   inflating: full_contract_txt/BANGIINC_05_25_2005-EX-10-Premium Managed Hosting Agreement.txt
#   inflating: full_contract_txt/BANUESTRAFINANCIALCORP_09_08_2006-EX-10.16-AGENCY AGREEMENT.txt
#   inflating: full_contract_txt/BELLICUMPHARMACEUTICALS,INC_05_07_2019-EX-10.1-Supply Agreement.txt
#   inflating: full_contract_txt/BELLRINGBRANDS,INC_02_07_2020-EX-10.18-MASTER SUPPLY AGREEMENT.txt
#   inflating: full_contract_txt/BellringBrandsInc_20190920_S-1_EX-10.12_11817081_EX-10.12_Manufacturing Agreement1.txt
#   inflating: full_contract_txt/BellringBrandsInc_20190920_S-1_EX-10.12_11817081_EX-10.12_Manufacturing Agreement2.txt
#   inflating: full_contract_txt/BellringBrandsInc_20190920_S-1_EX-10.12_11817081_EX-10.12_Manufacturing Agreement3.txt
#   inflating: full_contract_txt/BellringBrandsInc_20190920_S-1_EX-10.12_11817081_EX-10.12_Manufacturing Agreement4.txt
#   inflating: full_contract_txt/BERKELEYLIGHTS,INC_06_26_2020-EX-10.12-COLLABORATION AGREEMENT.txt
#   inflating: full_contract_txt/BerkshireHillsBancorpInc_20120809_10-Q_EX-10.16_7708169_EX-10.16_Endorsement Agreement.txt
#   inflating: full_contract_txt/BEYONDCOMCORP_08_03_2000-EX-10.2-CO-HOSTING AGREEMENT.txt
#   inflating: full_contract_txt/BICYCLETHERAPEUTICSPLC_03_10_2020-EX-10.11-SERVICE AGREEMENT.txt
#   inflating: full_contract_txt/BIOAMBERINC_04_10_2013-EX-10.34-DEVELOPMENT AGREEMENT (1).txt
#   inflating: full_contract_txt/BIOAMBERINC_04_10_2013-EX-10.34-DEVELOPMENT AGREEMENT - First Amendment.txt
#   inflating: full_contract_txt/BIOCEPTINC_08_19_2013-EX-10-COLLABORATION AGREEMENT.txt
#   inflating: full_contract_txt/BIOFRONTERAAG_04_29_2019-EX-4.17-SUPPLY AGREEMENT.txt
#   inflating: full_contract_txt/BIOPURECORP_06_30_1999-EX-10.13-AGENCY AGREEMENT.txt
#   inflating: full_contract_txt/BizzingoInc_20120322_8-K_EX-10.17_7504499_EX-10.17_Endorsement Agreement.txt
#   inflating: full_contract_txt/BLACKBOXSTOCKSINC_08_05_2014-EX-10.1-DISTRIBUTOR AGREEMENT.txt
#   inflating: full_contract_txt/BLACKROCKMUNIHOLDINGSINVESTMENTQUALITYFUND_04_07_2020-EX-99.01-JOINT FILING AGREEMENT.txt
#   inflating: full_contract_txt/BLACKSTONEGSOLONG-SHORTCREDITINCOMEFUND_05_11_2020-EX-99.(K)(1)-SERVICE AGREEMENT.txt
#   inflating: full_contract_txt/BloomEnergyCorp_20180321_DRSA (on S-1)_EX-10_11240356_EX-10_Maintenance Agreement.txt
#   inflating: full_contract_txt/BLUEFLYINC_03_27_2002-EX-10.27-e-business Hosting Agreement.txt
#   inflating: full_contract_txt/BLUEHILLSBANCORP,INC_05_20_2014-EX-1.1-AGENCY AGREEMENT.txt
#   inflating: full_contract_txt/BLUEROCKRESIDENTIALGROWTHREIT,INC_06_01_2016-EX-1.1-AGENCY AGREEMENT.txt
#   inflating: full_contract_txt/BNCMORTGAGEINC_05_17_1999-EX-10.4-LICENSING AND WEB SITE HOSTING AGREEMENT.txt
#   inflating: full_contract_txt/BNLFINANCIALCORP_03_30_2007-EX-10.8-OUTSOURCING AGREEMENT.txt
#   inflating: full_contract_txt/BOLIVARMININGCORP_05_23_2003-EX-2.1-VISP WEB SITE BUILDING AND HOSTING AGREEMENT.txt
#   inflating: full_contract_txt/BONTONSTORESINC_04_20_2018-EX-99.3-AGENCY AGREEMENT.txt
#   inflating: full_contract_txt/BORROWMONEYCOM,INC_06_11_2020-EX-10.1-JOINT VENTURE AGREEMENT.txt
#   inflating: full_contract_txt/BravatekSolutionsInc_20170418_8-K_EX-10.1_10205739_EX-10.1_Reseller Agreement.txt
#   inflating: full_contract_txt/BUFFALOWILDWINGSINC_06_05_1998-EX-10.3-FRANCHISE AGREEMENT.txt
#   inflating: full_contract_txt/CANOPETROLEUM,INC_12_13_2007-EX-10.1-Sponsorship Agreement.txt
#   inflating: full_contract_txt/CARDAX,INC_08_19_2014-EX-10.1-COLLABORATION AGREEMENT.txt
#   inflating: full_contract_txt/CardlyticsInc_20180112_S-1_EX-10.16_11002987_EX-10.16_Maintenance Agreement1.txt
#   inflating: full_contract_txt/CardlyticsInc_20180112_S-1_EX-10.16_11002987_EX-10.16_Maintenance Agreement2.txt
#   inflating: full_contract_txt/CardlyticsInc_20180112_S-1_EX-10.16_11002987_EX-10.16_Maintenance Agreement3.txt
#   inflating: full_contract_txt/CardlyticsInc_20180112_S-1_EX-10.16_11002987_EX-10.16_Maintenance Agreement4.txt
#   inflating: full_contract_txt/CCAINDUSTRIESINC_04_14_2014-EX-10.1-OUTSOURCING AGREEMENT.txt
#   inflating: full_contract_txt/CcRealEstateIncomeFundadv_20181205_POS 8C_EX-99.(H)(3)_11447739_EX-99.(H)(3)_Marketing Agreement.txt
#   inflating: full_contract_txt/CENTRACKINTERNATIONALINC_10_29_1999-EX-10.3-WEB SITE HOSTING AGREEMENT.txt
#   inflating: full_contract_txt/CerenceInc_20191002_8-K_EX-10.4_11827494_EX-10.4_Intellectual Property Agreement.txt
#   inflating: full_contract_txt/CERES,INC_01_25_2012-EX-10.20-Collaboration Agreement.txt
#   inflating: full_contract_txt/Cerus Corporation - FIRST AMEND TO SUPPLY AND MANUFACTURING AGREEMENT.txt
#   inflating: full_contract_txt/CHANGEPOINTCORP_03_08_2000-EX-10.6-LICENSE AND HOSTING AGREEMENT.txt
#   inflating: full_contract_txt
ERAVANCEBIOPHARMA,INC_05_08_2020-EX-10.2-SERVICE AGREEMENT.txt
#   inflating: full_contract_txt/ThriventVariableInsuranceAccountB_20190701_N-6_EX-99.D(IV)_11720968_EX-99.D(IV)_Endorsement Agreement.txt
#   inflating: full_contract_txt/TICKETSCOMINC_06_22_1999-EX-10.22-SPONSORSHIP AGREEMENT.txt
#   inflating: full_contract_txt/TodosMedicalLtd_20190328_20-F_EX-4.10_11587157_EX-4.10_Marketing Agreement_ Reseller Agreement.txt
#   inflating: full_contract_txt/TomOnlineInc_20060501_20-F_EX-4.46_749700_EX-4.46_Co-Branding Agreement.txt
#   inflating: full_contract_txt/TRANSMONTAIGNEPARTNERSLLC_03_13_2020-EX-10.9-SERVICES AGREEMENT.txt
#   inflating: full_contract_txt/TRANSPHORM,INC_02_14_2020-EX-10.12(1)-JOINT VENTURE AGREEMENT.txt
#   inflating: full_contract_txt/TRICITYBANKSHARESCORP_05_15_1998-EX-10-OUTSOURCING AGREEMENT.txt
#   inflating: full_contract_txt/TRIZETTOGROUPINC_08_18_1999-EX-10.17-TECHNICAL INFRASTRUCTURE MAINTENANCE AGREEMENT.txt
#   inflating: full_contract_txt/TRUENORTHENERGYCORP_02_08_2007-EX-10.1-DEVELOPMENT AGREEMENT.txt
#   inflating: full_contract_txt/TubeMediaCorp_20060310_8-K_EX-10.1_513921_EX-10.1_Affiliate Agreement.txt
#   inflating: full_contract_txt/TUNIUCORP_03_06_2014-EX-10-COOPERATION AGREEMENT.txt
#   inflating: full_contract_txt/TURNKEYCAPITAL,INC_07_20_2017-EX-1.1-Strategic Alliance Agreement.txt
#   inflating: full_contract_txt/UAGHINC_04_14_2004-EX-10.18-MAINTENANCE AGREEMENT.txt
#   inflating: full_contract_txt/ULTRAGENYXPHARMACEUTICALINC_12_23_2013-EX-10.9-SUPPLY AGREEMENT.txt
#   inflating: full_contract_txt/UnionDentalHoldingsInc_20050204_8-KA_EX-10_3345577_EX-10_Affiliate Agreement.txt
#   inflating: full_contract_txt/UNITEDNATIONALBANCORP_03_03_1999-EX-99-Outsourcing Agreement with the BISYS Group, Inc..txt
#   inflating: full_contract_txt/UpjohnInc_20200121_10-12G_EX-2.6_11948692_EX-2.6_Manufacturing Agreement_ Supply Agreement.txt
#   inflating: full_contract_txt/URSCORPNEW_03_17_2014-EX-99-COOPERATION AGREEMENT.txt
#   inflating: full_contract_txt/USASYNTHETICFUELCORP_10_21_2010-EX-10.10-STRATEGIC ALLIANCE AGREEMENT.txt
#   inflating: full_contract_txt/UsioInc_20040428_SB-2_EX-10.11_1723988_EX-10.11_Affiliate Agreement 2.txt
#   inflating: full_contract_txt/VALENCETECHNOLOGYINC_02_14_2003-EX-10-JOINT VENTURE CONTRACT.txt
#   inflating: full_contract_txt/VAPOTHERM, INC. - Manufacturing and Supply Agreement.txt
#   inflating: full_contract_txt/VARIABLESEPARATEACCOUNT_04_30_2014-EX-13.C-UNCONDITIONAL CAPITAL MAINTENANCE AGREEMENT.txt
#   inflating: full_contract_txt/VAXCYTE,INC_05_22_2020-EX-10.19-SUPPLY AGREEMENT.txt
#   inflating: full_contract_txt/VEONEER,INC_02_21_2020-EX-10.11-JOINT VENTURE AGREEMENT.txt
#   inflating: full_contract_txt/VERICELCORP_08_06_2019-EX-10.10-SUPPLY AGREEMENT.txt
#   inflating: full_contract_txt/VerizonAbsLlc_20200123_8-K_EX-10.4_11952335_EX-10.4_Service Agreement.txt
#   inflating: full_contract_txt/VERSOTECHNOLOGIESINC_12_28_2007-EX-99.3-INTELLECTUAL PROPERTY AGREEMENT.txt
#   inflating: full_contract_txt/VERTEXENERGYINC_08_14_2014-EX-10.24-OPERATION AND MAINTENANCE AGREEMENT.txt
#   inflating: full_contract_txt/VertexEnergyInc_20200113_8-K_EX-10.1_11943624_EX-10.1_Marketing Agreement.txt
#   inflating: full_contract_txt/VERTICALNETINC_04_01_2002-EX-10.19-MAINTENANCE AND SUPPORT AGREEMENT.txt
#   inflating: full_contract_txt/VgrabCommunicationsInc_20200129_10-K_EX-10.33_11958828_EX-10.33_Development Agreement.txt
#   inflating: full_contract_txt/VIOLINMEMORYINC_12_12_2012-EX-10.14-SPONSORSHIP AGREEMENT.txt
#   inflating: full_contract_txt/VIRGINGALACTICHOLDINGS,INC_04_08_2020-EX-99.1-JOINT FILING STATEMENT.txt
#   inflating: full_contract_txt/VIRTUALSCOPICS,INC_11_12_2010-EX-10.1-STRATEGIC ALLIANCE AGREEMENT.txt
#   inflating: full_contract_txt/VirtuosoSurgicalInc_20191227_1-A_EX1A-6 MAT CTRCT_11933379_EX1A-6 MAT CTRCT_License Agreement.txt
#   inflating: full_contract_txt/VISIUMTECHNOLOGIES,INC_10_20_2004-EX-10.20-DISTRIBUTOR AGREEMENT.txt
#   inflating: full_contract_txt/VitalibisInc_20180316_8-K_EX-10.2_11100168_EX-10.2_Hosting Agreement.txt
#   inflating: full_contract_txt/VITAMINSHOPPECOMINC_09_13_1999-EX-10.26-SPONSORSHIP AGREEMENT.txt
#   inflating: full_contract_txt/VIVINT SOLAR, INC. - NON-COMPETITION AGREEMENT.txt
#   inflating: full_contract_txt/VNUE,INC_07_10_2015-EX-10.1-SPONSORSHIP AGREEMENT.txt
#   inflating: full_contract_txt/VnueInc_20150914_8-K_EX-10.1_9259571_EX-10.1_Promotion Agreement.txt
#   inflating: full_contract_txt/WARNERCHILCOTTPLC_12_31_2003-EX-4.36-DEVELOPMENT AGREEMENT.txt
#   inflating: full_contract_txt/WARNINGMANAGEMENTSERVICESINC_12_10_1999-EX-10-ENDORSEMENT AGREEMENT.txt
#   inflating: full_contract_txt/WASTE2ENERGYHOLDINGS,INC_06_03_2010-EX-10.2-STRATEGIC ALLIANCE AGREEMENT.txt
#   inflating: full_contract_txt/WatchitMediaInc_20061201_8-K_EX-10.1_4148672_EX-10.1_Content License Agreement.txt
#   inflating: full_contract_txt/WaterNowInc_20191120_10-Q_EX-10.12_11900227_EX-10.12_Distributor Agreement.txt
#   inflating: full_contract_txt/WEBHELPCOMINC_03_22_2000-EX-10.8-HOSTING AGREEMENT.txt
#   inflating: full_contract_txt/WebmdHealthCorp_20050908_S-1A_EX-10.7_1027007_EX-10.7_Content License Agreement.txt
#   inflating: full_contract_txt/WELLSFARGOMORTGAGEBACKEDSECURITIES2006-6TRUST_05_11_2006-EX-10.3-Yield Maintenance Agreement.txt
#   inflating: full_contract_txt/WESTERN COPPER - NON-COMPETITION AGREEMENT.txt
#   inflating: full_contract_txt/WestPharmaceuticalServicesInc_20200116_8-K_EX-10.1_11947529_EX-10.1_Supply Agreement.txt
#   inflating: full_contract_txt/WHITESMOKE,INC_11_08_2011-EX-10.26-PROMOTION AND DISTRIBUTION AGREEMENT.txt
#   inflating: full_contract_txt/WOMENSGOLFUNLIMITEDINC_03_29_2000-EX-10.13-ENDORSEMENT AGREEMENT - Intellectual Property Rights                 Confidentiality and Non-Use Obligations Agreement.txt
#   inflating: full_contract_txt/WOMENSGOLFUNLIMITEDINC_03_29_2000-EX-10.13-ENDORSEMENT AGREEMENT.txt
#   inflating: full_contract_txt/WORLDWIDESTRATEGIESINC_11_02_2005-EX-10-RESELLER AGREEMENT.txt
#   inflating: full_contract_txt/WPPPLC_04_30_2020-EX-4.28-SERVICE AGREEMENT.txt
#   inflating: full_contract_txt/XACCT Technologies, Inc.SUPPORT AND MAINTENANCE AGREEMENT.txt
#   inflating: full_contract_txt/XENCORINC_10_25_2013-EX-10.24-COLLABORATION AGREEMENT (3).txt
#   inflating: full_contract_txt/XinhuaSportsEntertainmentLtd_20070221_F-1_EX-99.4_645553_EX-99.4_Content License Agreement.txt
#   inflating: full_contract_txt/XLITECHNOLOGIES,INC_12_02_2015-EX-10.02-STRATEGIC ALLIANCE AGREEMENT.txt
#   inflating: full_contract_txt/XLITECHNOLOGIES,INC_12_11_2015-EX-10.1-Sponsorship Agreement.txt
#   inflating: full_contract_txt/XpresspaGroupInc_20190401_10-K_EX-10.28_11599457_EX-10.28_Marketing Agreement.txt
#   inflating: full_contract_txt/XYBERNAUTCORP_07_12_2002-EX-4-SPONSORSHIP AGREEMENT.txt
#   inflating: full_contract_txt/ZEBRATECHNOLOGIESCORP_04_16_2014-EX-10.1-INTELLECTUAL PROPERTY AGREEMENT.txt
#   inflating: full_contract_txt/ZogenixInc_20190509_10-Q_EX-10.2_11663313_EX-10.2_Distributor Agreement.txt
#   inflating: full_contract_txt/ZONDWINDSYSTEMPARTNERSLTDSERIES85-B_04_03_2006-EX-10-MANAGEMENT AND MAINTENANCE AGREEMENT.txt
#   inflating: full_contract_txt/Zounds Hearing, Inc. - MANUFACTURING DESIGN MARKETING AGREEMENT.txt
#   inflating: full_contract_txt/ZtoExpressCaymanInc_20160930_F-1_EX-10.10_9752871_EX-10.10_Transportation Agreement.txt

# %%
# Imports and configuration
import os
import fitz  # PyMuPDF
import faiss
import numpy as np
from pathlib import Path
from sentence_transformers import SentenceTransformer
from langchain.text_splitter import CharacterTextSplitter
from ollama import Client

# Embedding model
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")
ollama_client = Client()

# Set chunking strategy
splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=200)

# Session state
session_state = {
    "active_index": "cuad",
    "cuad_index": None,
    "pdf_index": None,
    "cuad_chunks": [],
    "pdf_chunks": []
}
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
# Preload CUAD index from multiple .txt files
def build_cuad_index(txt_dir="full_contract_txt"):
    all_texts = []
    txt_dir_path = Path(txt_dir)
    if not txt_dir_path.exists():
        print(f"Error: Directory '{txt_dir}' not found.")
        return None, []
    for file in txt_dir_path.glob("*.txt"):
        with open(file, "r", encoding="utf-8") as f:
            text = f.read()
            chunks = splitter.split_text(text)
            all_texts.extend(chunks)

    if not all_texts:
        print("Error: No text content found in the specified directory.")
        return None, []

    print(f"Processing {len(all_texts)} text chunks.")
    embeddings = embedding_model.encode(all_texts, show_progress_bar=True)
    print(f"Embeddings shape: {embeddings.shape}")

    index = faiss.IndexFlatL2(embeddings.shape[1])
    index.add(np.array(embeddings))
    return index, all_texts

# Build or load
if os.path.exists("cuad_index.faiss") and os.path.exists("cuad_chunks.pkl"):
    print("🔄 Loading saved CUAD index...")
    session_state["cuad_index"] = faiss.read_index("cuad_index.faiss")
    import pickle
    with open("cuad_chunks.pkl", "rb") as f:
        session_state["cuad_chunks"] = pickle.load(f)
    print("✅ Loaded saved CUAD index.")
else:
    print("⚙️ Building CUAD index from .txt files...")
    session_state["cuad_index"], session_state["cuad_chunks"] = build_cuad_index()
    faiss.write_index(session_state["cuad_index"], "cuad_index.faiss")
    with open("cuad_chunks.pkl", "wb") as f:
        pickle.dump(session_state["cuad_chunks"], f)
    print("✅ Built and saved CUAD index.")
# Out:
# Streaming output truncated to the last 5000 lines.
# WARNING:langchain_text_splitters.base:Created a chunk of size 1157, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1597, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1138, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1063, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2005, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3803, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2024, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1204, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1462, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 5053, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1301, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1121, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1029, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2492, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1340, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1198, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1107, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1094, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1683, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1318, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1006, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3237, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2883, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2976, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2946, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2527, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1146, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1015, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1038, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1203, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1166, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1362, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1236, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1713, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1005, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1086, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1204, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1059, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1556, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1002, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2502, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2413, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1917, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2386, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2833, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3033, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3175, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3417, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2759, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3301, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1318, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2931, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1180, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1496, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1523, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1733, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1486, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1500, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1135, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2513, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1605, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1888, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2749, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2553, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2760, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3011, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2354, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2768, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1997, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2096, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1880, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1443, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1083, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1725, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1132, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2059, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3315, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1047, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1394, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1587, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1498, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2505, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3983, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1823, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1434, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1021, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1093, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1740, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1120, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1060, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1845, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1859, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1069, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1083, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1002, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2465, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3475, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1193, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1002, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1015, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1366, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1133, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1212, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1725, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1057, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1155, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1211, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1170, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2449, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1456, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1734, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1565, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1059, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 
which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1247, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1258, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1010, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1266, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1070, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1148, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1008, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1027, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1027, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1048, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1127, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1567, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1473, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1262, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1346, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1717, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2665, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1500, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1543, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3274, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3248, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 5173, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1768, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1485, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1436, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1568, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1186, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1069, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1604, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1007, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1251, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1264, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1350, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1027, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1839, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2212, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1910, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2019, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3489, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2551, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2807, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4026, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3488, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3544, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3188, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4150, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1908, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2745, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3814, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2853, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2062, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2561, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2820, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2144, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2847, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3581, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1048, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2627, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2128, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2964, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3222, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3138, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4733, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3381, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3566, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3682, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3334, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3459, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2589, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3718, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2856, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2819, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3485, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4711, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3826, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3136, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3605, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2863, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2994, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2199, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2258, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2086, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2924, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1324, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1916, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1222, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1491, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1551, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1206, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1121, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1818, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2756, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4170, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2620, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1022, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3468, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1767, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3721, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2410, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1041, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2999, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1434, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2756, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1497, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1602, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3875, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3532, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1445, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4024, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2556, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2712, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1111, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2516, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1984, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2342, which is longer than the specified 1000
# Processing 27018 text chunks.
# Batches:   0%|          | 0/845 [00:00<?, ?it/s]
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Embeddings shape: (27018, 384)
# ✅ CUAD index ready.

# %%
# Save FAISS index and chunks
faiss.write_index(session_state["cuad_index"], "cuad_index.faiss")

import pickle
with open("cuad_chunks.pkl", "wb") as f:
    pickle.dump(session_state["cuad_chunks"], f)

print("✅ CUAD index and chunks saved.")
# Out:
# ✅ CUAD index and chunks saved.

# %%
# Process a new uploaded PDF (simulate with a sample file)
def process_pdf_to_index(pdf_path="data/sample_contract.pdf"):
    doc = fitz.open(pdf_path)
    text = "".join(page.get_text() for page in doc)
    chunks = splitter.split_text(text)
    embeddings = embedding_model.encode(chunks, show_progress_bar=True)
    index = faiss.IndexFlatL2(embeddings.shape[1])
    index.add(np.array(embeddings))
    return index, chunks

# Load and process sample PDF
session_state["pdf_index"], session_state["pdf_chunks"] = process_pdf_to_index()
session_state["active_index"] = "pdf"  # Switch to PDF as active
print("✅ PDF index created and set as active.")
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ✅ PDF index created and set as active.
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)

# %%
from google.colab import userdata
import google.generativeai as genai
import os

def retrieve_top_k(query, model, index, texts, k=3):
    query_embedding = model.encode([query])
    distances, indices = index.search(np.array(query_embedding), k)
    return [texts[i] for i in indices[0]]

def generate_answer(question, top_chunks):
    context = "\n\n".join(top_chunks)
    prompt = f"""You are a legal contract assistant. Answer the question below using only the given context.

Context:
{context}

Question: {question}

Answer:"""
    # Set Gemini API key
    genai.configure(api_key=userdata.get('GOOGLE_API_KEY'))  

    # Initialize model
    llm = genai.GenerativeModel("gemini-2.5-pro")

    response = llm.generate_content(prompt)
    return response.text

# Ask a question using current active index
question = "What is the governing law of this agreement?"
if session_state["active_index"] == "pdf":
    top_chunks = retrieve_top_k(question, embedding_model, session_state["pdf_index"], session_state["pdf_chunks"])
else:
    top_chunks = retrieve_top_k(question, embedding_model, session_state["cuad_index"], session_state["cuad_chunks"])

answer = generate_answer(question, top_chunks)
print("🧠 Answer:", answer)
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# 🧠 Answer: Based on the context provided, Section 23, "Governing Law," states: "This Agreement will be governed in all respects by the laws of the State of Delaware, including its conflict with law provisions."
